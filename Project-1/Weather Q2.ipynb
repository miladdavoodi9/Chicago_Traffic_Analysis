# %%
#In what season do most crashes occur? (per month)
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import csv

# %%
#Create reference to CSV file for second file
csv_path_crashes = "../Resources/Traffic_Crashes_-_Crashes.csv"

df2 = pd.read_csv(csv_path_crashes, low_memory=False)

# %%
df = df2

# %%
df
# Out:
#            RD_NO CRASH_DATE_EST_I              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0       JC123097              NaN  01/19/2019 11:45:00 PM                  30
# 1       JC123084              NaN  01/19/2019 11:30:00 PM                  30
# 2       JC123076              NaN  01/19/2019 11:16:00 PM                  25
# 3       JC123075              NaN  01/19/2019 11:15:00 PM                  30
# 4       JC123050                Y  01/19/2019 10:52:00 PM                  30
# ...          ...              ...                     ...                 ...
# 261260  HY498942                Y  11/11/2014 08:00:00 PM                  30
# 261261  HZ400518              NaN  08/20/2014 04:50:00 PM                   0
# 261262  HZ164689              NaN  02/24/2014 07:45:00 PM                  30
# 261263  HZ122950              NaN  01/21/2014 07:40:00 AM                  30
# 261264  JB442550              NaN  01/18/2014 06:14:00 PM                  30
#
#        TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0              TRAFFIC SIGNAL               UNKNOWN              SNOW
# 1                 NO CONTROLS           NO CONTROLS              SNOW
# 2           STOP SIGN/FLASHER  FUNCTIONING PROPERLY              SNOW
# 3                 NO CONTROLS           NO CONTROLS              SNOW
# 4              TRAFFIC SIGNAL  FUNCTIONING PROPERLY              SNOW
# ...                       ...                   ...               ...
# 261260            NO CONTROLS           NO CONTROLS           UNKNOWN
# 261261            NO CONTROLS           NO CONTROLS             CLEAR
# 261262         TRAFFIC SIGNAL  FUNCTIONING PROPERLY              RAIN
# 261263                  YIELD           NO CONTROLS             CLEAR
# 261264            NO CONTROLS           NO CONTROLS             CLEAR
#
#             LIGHTING_CONDITION          FIRST_CRASH_TYPE  \
# 0       DARKNESS, LIGHTED ROAD                  REAR END
# 1       DARKNESS, LIGHTED ROAD              PEDALCYCLIST
# 2       DARKNESS, LIGHTED ROAD                     ANGLE
# 3       DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION
# 4       DARKNESS, LIGHTED ROAD                  REAR END
# ...                        ...                       ...
# 261260                 UNKNOWN      PARKED MOTOR VEHICLE
# 261261                DAYLIGHT                  REAR END
# 261262                DAYLIGHT                   TURNING
# 261263                DAYLIGHT                     ANGLE
# 261264                    DUSK      PARKED MOTOR VEHICLE
#
#                         TRAFFICWAY_TYPE  ... INJURIES_NON_INCAPACITATING  \
# 0       DIVIDED - W/MEDIAN (NOT RAISED)  ...                         0.0
# 1                           NOT DIVIDED  ...                         0.0
# 2       DIVIDED - W/MEDIAN (NOT RAISED)  ...                         0.0
# 3            DIVIDED - W/MEDIAN BARRIER  ...                         0.0
# 4                           NOT DIVIDED  ...                         0.0
# ...                                 ...  ...                         ...
# 261260  DIVIDED - W/MEDIAN (NOT RAISED)  ...                         0.0
# 261261                      NOT DIVIDED  ...                         0.0
# 261262                      NOT DIVIDED  ...                         0.0
# 261263  DIVIDED - W/MEDIAN (NOT RAISED)  ...                         1.0
# 261264       DIVIDED - W/MEDIAN BARRIER  ...                         0.0
#
#        INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                                0.0                    2.0              0.0
# 1                                1.0                    1.0              0.0
# 2                                0.0                    2.0              0.0
# 3                                0.0                    2.0              0.0
# 4                                0.0                    2.0              0.0
# ...                              ...                    ...              ...
# 261260                           0.0                    1.0              0.0
# 261261                           0.0                    2.0              0.0
# 261262                           0.0                    2.0              0.0
# 261263                           0.0                    1.0              0.0
# 261264                           0.0                    2.0              0.0
#
#        CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0              23                 7           1  41.859566 -87.659525
# 1              23                 7           1  41.928335 -87.699915
# 2              23                 7           1  41.870048 -87.715673
# 3              23                 7           1  41.876569 -87.686450
# 4              22                 7           1  41.946837 -87.690697
# ...           ...               ...         ...        ...        ...
# 261260         20                 3          11  41.998270 -87.662997
# 261261         16                 4           8  41.751143 -87.607091
# 261262         19                 2           2  41.884016 -87.701143
# 261263          7                 3           1  41.760710 -87.561946
# 261264         18                 7           1  41.885610 -87.638756
#
#                                         LOCATION
# 0       POINT (-87.659524513506 41.859565972988)
# 1       POINT (-87.699915181766 41.928335036314)
# 2       POINT (-87.715673407351 41.870048406533)
# 3       POINT (-87.686449738767 41.876568874081)
# 4       POINT (-87.690696829341 41.946837390731)
# ...                                          ...
# 261260  POINT (-87.662996825424 41.998269693725)
# 261261  POINT (-87.607090627909 41.751143217534)
# 261262  POINT (-87.701142757538 41.884016475152)
# 261263  POINT (-87.561946030143 41.760710194223)
# 261264  POINT (-87.638756189808 41.885609917063)
#
# [261265 rows x 48 columns]

# %%
df.WEATHER_CONDITION.value_counts()
# Out:
# CLEAR                     207485
# RAIN                       23803
# UNKNOWN                    11400
# SNOW                        9077
# CLOUDY/OVERCAST             7753
# OTHER                        799
# FOG/SMOKE/HAZE               552
# SLEET/HAIL                   344
# SEVERE CROSS WIND GATE        52
# Name: WEATHER_CONDITION, dtype: int64

# %%
df.index = pd.to_datetime(df['CRASH_DATE'])

# %%
monthly_ordered = df.index.month.value_counts().sort_index()

# %%
mo = pd.DataFrame(monthly_ordered)

# %%
mo.index = ["January","February","March","April","May","June","July","August","September","October","November","December"]

# %%
mo.plot.bar()
plt.title("Amount of Crashes per month")
plt.xlabel("Months")
plt.ylabel("Crashes")
# Out:
# Text(0, 0.5, 'Crashes')

# %% [markdown]
# Question 2
# In what season do most crashes occur? (per month)
